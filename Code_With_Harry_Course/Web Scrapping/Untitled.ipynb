# %%
import requests as rq

# %%
response = rq.get("https://github.com/AOSSIE-Org/Rein/issues?page=1")

# %%
with open(f"issue.html" , "w") as f :
            f.write(response.text) 
            print(f"Page scrapped and saved succesfully .")
# Out:
# Page scrapped and saved succesfully .
