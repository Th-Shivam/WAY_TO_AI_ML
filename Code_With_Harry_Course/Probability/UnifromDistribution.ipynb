# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.uniform(0,1,10)
plt.hist(data)
# Out:
# (array([1., 0., 0., 1., 1., 3., 1., 1., 1., 1.]),
#  array([0.24225494, 0.31780492, 0.39335489, 0.46890486, 0.54445483,
#         0.6200048 , 0.69555477, 0.77110475, 0.84665472, 0.92220469,
#         0.99775466]),
#  <BarContainer object of 10 artists>)

# %%
data = np.random.uniform(0,1,100)
plt.hist(data)
# Out:
# (array([15., 11., 15.,  9.,  8.,  7.,  8.,  7.,  8., 12.]),
#  array([0.00686551, 0.1031295 , 0.19939349, 0.29565749, 0.39192148,
#         0.48818547, 0.58444947, 0.68071346, 0.77697745, 0.87324145,
#         0.96950544]),
#  <BarContainer object of 10 artists>)

# %%
data = np.random.uniform(0,1,1000)
plt.hist(data)
# Out:
# (array([ 97., 110.,  97.,  98., 116., 109., 105., 105.,  79.,  84.]),
#  array([1.72080713e-04, 1.00112826e-01, 2.00053571e-01, 2.99994315e-01,
#         3.99935060e-01, 4.99875805e-01, 5.99816550e-01, 6.99757295e-01,
#         7.99698040e-01, 8.99638785e-01, 9.99579530e-01]),
#  <BarContainer object of 10 artists>)

# %%
data = np.random.uniform(0,1,10000)
plt.hist(data)
# Out:
# (array([1050.,  993.,  979., 1020.,  982., 1002.,  968., 1001.,  987.,
#         1018.]),
#  array([2.09720670e-04, 1.00187967e-01, 2.00166213e-01, 3.00144459e-01,
#         4.00122704e-01, 5.00100950e-01, 6.00079196e-01, 7.00057442e-01,
#         8.00035688e-01, 9.00013934e-01, 9.99992180e-01]),
#  <BarContainer object of 10 artists>)
